# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error as mse, r2_score
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
from sklearn.preprocessing import MinMaxScaler
from kan_p import *
import torch.nn as nn
import random
import torch.optim as optim

torch.set_default_dtype(torch.float64)
dtype = torch.get_default_dtype()

# %%
['te','thr','power']
# Out:
# ['te', 'thr', 'power']

# %%
df=pd.read_csv('data.csv',header=1)
df=df.drop(columns=['thr','te'])
current_target='power'

# %%
df = df.sort_index()
x = df.drop(columns=current_target)
y = df[current_target]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=59) #59 power, 80 thr, 70 te

# %% [markdown]
# for n in range(100):
#     df = df.sort_index()
#     x = df.drop(columns=current_target)
#     y = df[current_target]
#     x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=n)
#     model=CatBoostRegressor(verbose=False)
#     model.fit(x_train,y_train)
#     print(f"{n},{mse(model.predict(x_test),y_test)}")
#
# 1. Power
# 0,11.41076332145832
# 1,14.318056318234506
# 2,12.615432677258951
# 3,10.9692100087263
# 4,10.801517687064011
# 5,12.931889573120856
# 6,11.165391570447097
# 7,12.16917434260467
# 8,10.917127820213212
# 9,13.57935839615522
# 10,12.432077945680346
# 11,12.732707904845228
# 12,11.0327850528215
# 13,11.352214648250026
# 14,12.481151958841847
# 15,10.153587045462821
# 16,11.763529866459137
# 17,11.574598214644269
# 18,11.86273517180898
# 19,12.820310809775904
# 20,11.584763546706546
# 21,13.044937043699003
# 22,11.758697121516974
# 23,11.507046552519425
# 24,12.619511216698237
# 25,12.444032479758212
# 26,12.83678085135937
# 27,12.16733444132914
# 28,10.477083000524711
# 29,10.13846558623491
# 30,10.769794438586501
# 31,14.325811735855702
# 32,11.96672275368764
# 33,13.465696966404627
# 34,12.083252253261369
# 35,11.216962449702478
# 36,12.31491864162777
# 37,12.705542868757869
# 38,13.444925737482796
# 39,12.488122783940815
# 40,10.693394400966886
# 41,10.911616612947489
# 42,14.900715718684118
# 43,11.083119052178247
# 44,11.601977449220461
# 45,13.053408411244328
# 46,9.899147141321839
# 47,13.39057280005873
# 48,10.766648703492976
# 49,10.980290294937715
# 50,11.153880477145165
# 51,14.606199682745059
# 52,11.213925566348417
# 53,9.542522717059787
# 54,13.567374737730795
# 55,10.164773511928361
# 56,11.105287654265268
# 57,13.718719052701877
# 58,11.333540670353608
# 59,8.497001911326796
# 60,11.592424241690653
# 61,13.5395966025784
# 62,13.852712974886401
# 63,11.423705747028754
# 64,10.710872019194232
# 65,12.743530395528891
# 66,11.573257758357832
# 67,10.84146119086138
# 68,10.467392989379448
# 69,9.922823143106037
# 70,9.493745530032145
# 71,11.27202842133312
# 72,11.694136676152718
# 73,12.221674327283248
# 74,15.035725746620779
# 75,12.914080086013572
# 76,11.991917552718007
# 77,10.672710500953265
# 78,12.553205170616755
# 79,11.502409588056507
# 80,10.990264842503139
# 81,10.701090721830576
# 82,13.345973717809267
# 83,12.270014988052035
# 84,10.698777741688778
# 85,14.022644787847042
# 86,14.003823575109015
# 87,13.484354357882074
# 88,16.74424161345748
# 89,9.0584365100587
# 90,11.301090321941386
# 91,12.863339937586238
# 92,11.337603778800208
# 93,12.967600159536852
# 94,12.614455759261125
# 21,0.15738185286949172
# 22,0.13846191369281916
# 23,0.1309763419731059
# 24,0.11918574149788443
# 25,0.10849208544440343
# 26,0.12144241220933953
# 27,0.12429918742904165
# 28,0.12401341228278658
# 29,0.11909251835848811
# 30,0.12534313540457342
# 31,0.13772528292676176
# 32,0.14237334597556348
# 33,0.1149908016804011
# 34,0.11663034108936716
# 35,0.13345979870563054
# 36,0.13792373891235485
# 37,0.12592205404551512
# 38,0.11618716582806277
# 39,0.1236946549074161
# 40,0.1518154428950952
# 41,0.11899933800978037
# 42,0.1334104334260782
# 43,0.12044933316350703
# 44,0.15644423187185139
# 45,0.11238427912355291
# 46,0.1093926661253089
# 47,0.1201130262486998
# 48,0.12220893490988512
# 49,0.12923868597048924
# 50,0.11605447718880331
# 51,0.12517486697614424
# 52,0.134278481833615
# 53,0.13259484396574414
# 54,0.11609140521030992
# 55,0.12742532655420236
# 56,0.13499314819457234
# 57,0.10859403980356808
# 58,0.15071660643412657
# 59,0.10887781628174753
# 60,0.11741377662171941
# 61,0.11678822582000394
# 62,0.12946897402312088
# 63,0.10815875501883998
# 64,0.11519665336219592
# 65,0.14072289953879782
# 66,0.10680208387507033
# 67,0.11679001282570174
# 68,0.1458084399189047
# 69,0.12329664410950791
# 70,0.09896124419806995
# 71,0.110764527136708
# 72,0.11448840912744525
# 73,0.1157901878695587
# 74,0.12369770030845129
# 75,0.10520201257422472
# 76,0.11679178685757112
# 77,0.12821726185318374
# 78,0.10458019441962925
# 79,0.14107570991744922
# 80,0.1360445272398059
# 81,0.12478398220148712
# 82,0.13266027506933073
# 83,0.10607844562993962
# 84,0.10196898152963019
# 85,0.14104560101320465
# 86,0.1599296473332828
# 87,0.13068769078279674
# 88,0.11409966917269443
# 89,0.13619639359241678
# 90,0.12978284004793805
# 91,0.13149475644232786
# 92,0.14751679652468772
# 93,0.1440229546456236
# 94,0.14031287935662107
# 95,0.13745168842971403
# 96,0.12711315749420327
# 97,0.13488508250140588
# 98,0.12329059784840886
# 99,0.11539854443483825

# %%
def set_seed(seed=42):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)

set_seed(42)

# %%
dataset = {}
train_input=x_train.to_numpy()
train_label=y_train.to_numpy()
test_input=x_test.to_numpy()
test_label=y_test.to_numpy()

# %%
scaler_input = MinMaxScaler()

train_input_scaled = scaler_input.fit_transform(train_input)
test_input_scaled = scaler_input.transform(test_input)

dataset['train_input'] = torch.from_numpy(train_input_scaled).type(dtype)
dataset['test_input'] = torch.from_numpy(test_input_scaled).type(dtype)
dataset['train_label'] = torch.from_numpy(train_label[:,None]).type(dtype)
dataset['test_label'] = torch.from_numpy(test_label[:,None]).type(dtype)

# %%
space = {
    'grid_size': hp.quniform('grid_size', 1, 15, 1),
    'spline_order': hp.quniform('spline_order', 1, 10, 1),
    'scale_noise': hp.loguniform('scale_noise', np.log(1e-5), np.log(1e-1)),
    'scale_base': hp.loguniform('scale_base', np.log(1e-5), np.log(1e1)),
    'scale_spline': hp.loguniform('scale_spline', np.log(1e-5), np.log(1e1)),
    'learning_rate': hp.loguniform('learning_rate', np.log(1e-5), np.log(1e-1)),
    'lambda_l1': hp.loguniform('lambda_l1', np.log(1e-7), np.log(1e-1)),
    'lambda_l2': hp.loguniform('lambda_l2', np.log(1e-7), np.log(1e-1)),
    'grid_eps': hp.loguniform('grid_eps', np.log(1e-7), np.log(1e-1)),
    'non': hp.quniform('non', 8, 20, 2),
    'activation_scale': hp.uniform('activation_scale', 0.1, 10.0)  # Uniform distribution for activation_scale
}

# %%
param_df = pd.DataFrame(columns=['params', 'loss_curve_train', 'loss_curve_test', 'best_score'])
bestest_score = float('inf')
trial_no=0
  # Initialize global variable
def objective(params):
    global trial_no, bestest_score  # Declare global variables
    trial_no += 1
    params['grid_size'] = int(params['grid_size'])
    params['spline_order'] = int(params['spline_order'])
    params['non'] = int(params['non'])
    model = KAN(
        layers_hidden=[8, params['non'], 1],
        grid_size=params['grid_size'],
        spline_order=params['spline_order'],
        scale_noise=params['scale_noise'],
        scale_base=params['scale_base'],
        scale_spline=params['scale_spline'],
        base_activation=nn.SiLU,
        grid_eps=params['grid_eps'],
        grid_range=[0, 1],
        activation_scale=params['activation_scale']
    )
    
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=params['learning_rate'], weight_decay=params['lambda_l2'])
    num_epochs = 5000
    patience = 200
    best_loss = float('inf')
    epochs_no_improve = 0
    param_df['params'].loc[trial_no] = params
    training_loss = []
    test_loss = []
    set_seed(42)
    for epoch in range(num_epochs):
        set_seed(42)
        model.train()
        optimizer.zero_grad()
        predictions = model(dataset['train_input'])
        main_loss = criterion(predictions, dataset['train_label'])
        l1_loss = sum(p.abs().sum() for p in model.parameters())
        loss = main_loss + (params['lambda_l1'] * l1_loss)
        loss.backward()
        optimizer.step()
        training_loss.append(loss.item())
        
        model.eval()
        with torch.no_grad():
            val_predictions = model(dataset['test_input'])
            temp_score = mse(dataset['test_label'].cpu().numpy(), val_predictions.cpu().numpy())**0.5  # Move tensors to CPU before numpy
        test_loss.append(temp_score)
        
        if temp_score < best_loss:
            best_loss = temp_score
            epochs_no_improve = 0
            best_model_state = model.state_dict()
        else:
            epochs_no_improve += 1
        
        if epochs_no_improve >= patience:
            model.load_state_dict(best_model_state)
            break
        
        # Update the bestest score
        if temp_score < bestest_score:
            bestest_score = temp_score
            torch.save({'model_state_dict': best_model_state, 'params': params}, f"{current_target}_bestest_model.pth")
    
    model.eval()
    with torch.no_grad():
        test_predictions = model(dataset['test_input'])
    score = mse(dataset['test_label'].numpy(), test_predictions.numpy())**0.5  # Move tensors to CPU before numpy
    param_df.loc[trial_no] = [params, training_loss, test_loss, score]
    print(score)
    print(params)
    return score

# %%
trials = Trials()
best_params = fmin(fn=objective,
                   space=space,
                   algo=tpe.suggest,
                   max_evals=50,
                   trials=trials)
print("Best hyperparameters:", best_params)
# Out:
# 410.31342803318915
# {'activation_scale': 7.453179389458269, 'grid_eps': 0.013897136226480365, 'grid_size': 6, 'lambda_l1': 0.00011179791043887879, 'lambda_l2': 5.880705891285438e-07, 'learning_rate': 3.1077484650251505e-05, 'non': 18, 'scale_base': 0.05101300363996505, 'scale_noise': 1.4231713684818313e-05, 'scale_spline': 1.84187560852901, 'spline_order': 6}
# 219.73524461009785
# Best hyperparameters: {'activation_scale': 6.919738069936537, 'grid_eps': 0.0915995590576604, 'grid_size': 4.0, 'lambda_l1': 1.981671723115777e-05, 'lambda_l2': 0.0014268305019756566, 'learning_rate': 0.0007506068250835023, 'non': 18.0, 'scale_base': 0.6547846966789029, 'scale_noise': 0.01870128240439823, 'scale_spline': 0.03408628276595522, 'spline_order': 6.0}

# %%
param_df.to_csv(f'param_df{current_target}.csv')

# %%
checkpoint = torch.load(f"{current_target}_bestest_model.pth")
params1 = checkpoint['params']
model = KAN(
    layers_hidden=[8, params1['non'], 1],
    grid_size=params1['grid_size'],
    spline_order=params1['spline_order'],
    scale_noise=params1['scale_noise'],
    scale_base=params1['scale_base'],
    scale_spline=params1['scale_spline'],
    base_activation=nn.SiLU,
    grid_eps=params1['grid_eps'],
    grid_range=[0, 1],
    activation_scale=params1['activation_scale']
)
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_5956\836558021.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(f"{current_target}_bestest_model.pth")
# <All keys matched successfully>

# %%
model.eval()
with torch.no_grad():
    test_predictions = model(dataset['test_input'])
mse(dataset['test_label'].numpy(), test_predictions.numpy())**0.5
# Out:
# 1.963566009325987

# %%
r2_score(dataset['test_label'].numpy(), test_predictions.numpy())
# Out:
# 0.9995324780245904

# %% [markdown]
# # Second Ouput

# %%
df=pd.read_csv('data.csv',header=1)
df=df.drop(columns=['power','te'])
current_target='thr'

# %%
df = df.sort_index()
x = df.drop(columns=current_target)
y = df[current_target]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=80) #59 power, 80 thr, 70 te
set_seed(42)

# %%
dataset = {}
train_input=x_train.to_numpy()
train_label=y_train.to_numpy()
test_input=x_test.to_numpy()
test_label=y_test.to_numpy()

# %%
scaler_input = MinMaxScaler()

train_input_scaled = scaler_input.fit_transform(train_input)
test_input_scaled = scaler_input.transform(test_input)

dataset['train_input'] = torch.from_numpy(train_input_scaled).type(dtype)
dataset['test_input'] = torch.from_numpy(test_input_scaled).type(dtype)
dataset['train_label'] = torch.from_numpy(train_label[:,None]).type(dtype)
dataset['test_label'] = torch.from_numpy(test_label[:,None]).type(dtype)

# %%
space = {
    'grid_size': hp.quniform('grid_size', 1, 15, 1),
    'spline_order': hp.quniform('spline_order', 1, 10, 1),
    'scale_noise': hp.loguniform('scale_noise', np.log(1e-5), np.log(1e-1)),
    'scale_base': hp.loguniform('scale_base', np.log(1e-5), np.log(1e1)),
    'scale_spline': hp.loguniform('scale_spline', np.log(1e-5), np.log(1e1)),
    'learning_rate': hp.loguniform('learning_rate', np.log(1e-5), np.log(1e-1)),
    'lambda_l1': hp.loguniform('lambda_l1', np.log(1e-7), np.log(1e-1)),
    'lambda_l2': hp.loguniform('lambda_l2', np.log(1e-7), np.log(1e-1)),
    'grid_eps': hp.loguniform('grid_eps', np.log(1e-7), np.log(1e-1)),
    'non': hp.quniform('non', 8, 20, 2),
    'activation_scale': hp.uniform('activation_scale', 0.1, 10.0)  # Uniform distribution for activation_scale
}

# %%
param_df = pd.DataFrame(columns=['params', 'loss_curve_train', 'loss_curve_test', 'best_score'])
bestest_score = float('inf')
trial_no=0
  # Initialize global variable
def objective(params):
    global trial_no, bestest_score  # Declare global variables
    trial_no += 1
    params['grid_size'] = int(params['grid_size'])
    params['spline_order'] = int(params['spline_order'])
    params['non'] = int(params['non'])
    model = KAN(
        layers_hidden=[8, params['non'], 1],
        grid_size=params['grid_size'],
        spline_order=params['spline_order'],
        scale_noise=params['scale_noise'],
        scale_base=params['scale_base'],
        scale_spline=params['scale_spline'],
        base_activation=nn.SiLU,
        grid_eps=params['grid_eps'],
        grid_range=[0, 1],
        activation_scale=params['activation_scale']
    )
    
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=params['learning_rate'], weight_decay=params['lambda_l2'])
    num_epochs = 5000
    patience = 200
    best_loss = float('inf')
    epochs_no_improve = 0
    param_df['params'].loc[trial_no] = params
    training_loss = []
    test_loss = []
    set_seed(42)
    for epoch in range(num_epochs):
        set_seed(42)
        model.train()
        optimizer.zero_grad()
        predictions = model(dataset['train_input'])
        main_loss = criterion(predictions, dataset['train_label'])
        l1_loss = sum(p.abs().sum() for p in model.parameters())
        loss = main_loss + (params['lambda_l1'] * l1_loss)
        loss.backward()
        optimizer.step()
        training_loss.append(loss.item())
        
        model.eval()
        with torch.no_grad():
            val_predictions = model(dataset['test_input'])
            temp_score = mse(dataset['test_label'].cpu().numpy(), val_predictions.cpu().numpy())**0.5  # Move tensors to CPU before numpy
        test_loss.append(temp_score)
        
        if temp_score < best_loss:
            best_loss = temp_score
            epochs_no_improve = 0
            best_model_state = model.state_dict()
        else:
            epochs_no_improve += 1
        
        if epochs_no_improve >= patience:
            model.load_state_dict(best_model_state)
            break
        
        # Update the bestest score
        if temp_score < bestest_score:
            bestest_score = temp_score
            torch.save({'model_state_dict': best_model_state, 'params': params}, f"{current_target}_bestest_model.pth")
    
    model.eval()
    with torch.no_grad():
        test_predictions = model(dataset['test_input'])
    score = mse(dataset['test_label'].numpy(), test_predictions.numpy())**0.5  # Move tensors to CPU before numpy
    param_df.loc[trial_no] = [params, training_loss, test_loss, score]
    print(score)
    print(params)
    return score

# %%
trials = Trials()
best_params = fmin(fn=objective,
                   space=space,
                   algo=tpe.suggest,
                   max_evals=50,
                   trials=trials)
print("Best hyperparameters:", best_params)
# Out:
# 68.62474673870584
# {'activation_scale': 9.841825751730061, 'grid_eps': 0.00015005593367406613, 'grid_size': 10, 'lambda_l1': 7.231436911227181e-06, 'lambda_l2': 0.016948434046764202, 'learning_rate': 0.08956756306995363, 'non': 16, 'scale_base': 0.006846201525305479, 'scale_noise': 1.1519307591041363e-05, 'scale_spline': 0.0001248048731884559, 'spline_order': 3}
# 63.48549664853094
# {'activation_scale': 9.578883900785899, 'grid_eps': 0.05603744154151416, 'grid_size': 5, 'lambda_l1': 1.2488738737806559e-06, 'lambda_l2': 3.7160086937667564e-06, 'learning_rate': 0.08496873843107351, 'non': 10, 'scale_base': 0.000751312489534341, 'scale_noise': 0.00013932054337600973, 'scale_spline': 0.2727804558214408, 'spline_order': 8}
# 63.01029311284397
# {'activation_scale': 4.536936951706722, 'grid_eps': 6.990112970481221e-07, 'grid_size': 2, 'lambda_l1': 0.00015514545942840432, 'lambda_l2': 0.0063497744881179, 'learning_rate': 0.014664756780666003, 'non': 16, 'scale_base': 0.03520798766008884, 'scale_noise': 0.008688930753701168, 'scale_spline': 0.04843230501798308, 'spline_order': 5}
# 6061.840030740818
# {'activation_scale': 7.506633209729381, 'grid_eps': 1.967921002287563e-06, 'grid_size': 8, 'lambda_l1': 3.674974674689415e-07, 'lambda_l2': 0.0011152092910392784, 'learning_rate': 0.03415417078354675, 'non': 16, 'scale_base': 3.141670879460255e-05, 'scale_noise': 0.0002335101675824595, 'scale_spline': 4.1937613162410435e-05, 'spline_order': 3}
# 66.08874157669979
# {'activation_scale': 6.996288065611107, 'grid_eps': 1.984064626233419e-05, 'grid_size': 12, 'lambda_l1': 1.1590913213934946e-07, 'lambda_l2': 1.3697785045160687e-06, 'learning_rate': 0.005511288204635243, 'non': 18, 'scale_base': 7.234274697335168, 'scale_noise': 0.022663658970469947, 'scale_spline': 0.0027837010385934973, 'spline_order': 10}
# 69.09683853761797
# {'activation_scale': 9.469627034972444, 'grid_eps': 0.0036962354330065395, 'grid_size': 14, 'lambda_l1': 1.6205067083771926e-07, 'lambda_l2': 0.0018376853849473007, 'learning_rate': 0.014288393126716509, 'non': 16, 'scale_base': 0.01087580626239941, 'scale_noise': 0.050207642247769274, 'scale_spline': 0.7904808043676409, 'spline_order': 6}
# 7886.494004219201
# {'activation_scale': 0.5249714290047701, 'grid_eps': 0.00036513400956330423, 'grid_size': 12, 'lambda_l1': 0.010566489449843933, 'lambda_l2': 3.64370134063512e-05, 'learning_rate': 9.27166173119438e-05, 'non': 10, 'scale_base': 0.13177768063471024, 'scale_noise': 2.8256455628243473e-05, 'scale_spline': 1.4023689980560297, 'spline_order': 9}
# 7840.194083873132
# {'activation_scale': 2.302505323099797, 'grid_eps': 0.017615029206329753, 'grid_size': 12, 'lambda_l1': 0.007048146064312938, 'lambda_l2': 0.0008977128124793165, 'learning_rate': 5.258135496155793e-05, 'non': 16, 'scale_base': 4.405379907418164, 'scale_noise': 0.007108523074497431, 'scale_spline': 0.014272154849172292, 'spline_order': 2}
# 5288.7528259746005
# {'activation_scale': 3.050430394386413, 'grid_eps': 0.00018514345025444373, 'grid_size': 12, 'lambda_l1': 2.1138617806144475e-06, 'lambda_l2': 3.138655689770682e-07, 'learning_rate': 0.00016588906979173796, 'non': 20, 'scale_base': 6.113747037344814e-05, 'scale_noise': 0.04641409479690516, 'scale_spline': 3.1840744735691313, 'spline_order': 6}
# 63.88022980947204
# {'activation_scale': 9.04678070543622, 'grid_eps': 2.938649821431258e-07, 'grid_size': 2, 'lambda_l1': 1.1748145053637407e-07, 'lambda_l2': 2.9185578272055836e-05, 'learning_rate': 0.06526923346084995, 'non': 12, 'scale_base': 0.5169607486914415, 'scale_noise': 0.00010586549918226021, 'scale_spline': 0.05264490872924702, 'spline_order': 8}
# 68.502640742209
# {'activation_scale': 0.7026199526968713, 'grid_eps': 3.559953584546693e-07, 'grid_size': 10, 'lambda_l1': 0.02906272888385944, 'lambda_l2': 0.0004254624193475119, 'learning_rate': 0.05829774421226888, 'non': 20, 'scale_base': 0.1423615211517031, 'scale_noise': 0.014445076602091564, 'scale_spline': 0.00015434215976138066, 'spline_order': 4}
# 65.31840041860164
# {'activation_scale': 1.518276517839176, 'grid_eps': 5.474184453563178e-07, 'grid_size': 6, 'lambda_l1': 7.798205611424095e-07, 'lambda_l2': 0.000849231668622724, 'learning_rate': 0.002128694988559549, 'non': 18, 'scale_base': 1.561702370601652, 'scale_noise': 0.03843262145722869, 'scale_spline': 0.03931764732802235, 'spline_order': 6}
# 7877.461098095188
# {'activation_scale': 4.9795360516812535, 'grid_eps': 3.2064973128080424e-06, 'grid_size': 6, 'lambda_l1': 4.402867263289475e-05, 'lambda_l2': 0.005164570705186121, 'learning_rate': 1.4808076180430655e-05, 'non': 8, 'scale_base': 0.000458897292550798, 'scale_noise': 0.0013202356751290702, 'scale_spline': 9.175443090608656, 'spline_order': 5}
# 64.92097244055626
# {'activation_scale': 5.101467474699794, 'grid_eps': 1.1475047128517252e-07, 'grid_size': 6, 'lambda_l1': 3.585886513298946e-05, 'lambda_l2': 0.0632112504431905, 'learning_rate': 0.0025692727595214918, 'non': 12, 'scale_base': 0.02548208942006439, 'scale_noise': 0.001574410665610391, 'scale_spline': 0.15292616929253608, 'spline_order': 7}
# 60.77273606646122
# {'activation_scale': 4.16625931823347, 'grid_eps': 0.001983253382880312, 'grid_size': 1, 'lambda_l1': 0.00016180393052642696, 'lambda_l2': 3.1562455922965976e-06, 'learning_rate': 0.017925854926990625, 'non': 8, 'scale_base': 0.02905294185869081, 'scale_noise': 0.0005395441762639075, 'scale_spline': 0.006856934976852015, 'spline_order': 4}
# 66.56574157866123
# {'activation_scale': 3.9580987153587444, 'grid_eps': 0.0019074952943396834, 'grid_size': 1, 'lambda_l1': 0.0001529210870435641, 'lambda_l2': 1.5312608073636896e-06, 'learning_rate': 0.018544174847133346, 'non': 8, 'scale_base': 0.025784679184295497, 'scale_noise': 0.0006010254575364298, 'scale_spline': 0.005545855583688776, 'spline_order': 4}
# 64.00002279279511
# {'activation_scale': 5.818428107868331, 'grid_eps': 0.0013605484454882952, 'grid_size': 1, 'lambda_l1': 0.0011478869326848533, 'lambda_l2': 1.3950904182015427e-05, 'learning_rate': 0.0054516310134750355, 'non': 12, 'scale_base': 0.603198874527699, 'scale_noise': 0.0035507999046155677, 'scale_spline': 0.024752397017071482, 'spline_order': 4}
# 63.23244529137763
# {'activation_scale': 3.794135933644435, 'grid_eps': 6.046117780473773e-06, 'grid_size': 2, 'lambda_l1': 0.00011697984073000385, 'lambda_l2': 0.08232685401169383, 'learning_rate': 0.006134961538344123, 'non': 12, 'scale_base': 0.040247747627887256, 'scale_noise': 0.08880900200543028, 'scale_spline': 0.0021389962476439125, 'spline_order': 2}
# 61.38567239467278
# {'activation_scale': 4.391027868863171, 'grid_eps': 0.006956875882665699, 'grid_size': 3, 'lambda_l1': 3.970094345891923e-05, 'lambda_l2': 0.0040185736027270914, 'learning_rate': 0.001374450763957556, 'non': 14, 'scale_base': 0.3315319028107408, 'scale_noise': 0.003067496419267537, 'scale_spline': 0.0061572530162008485, 'spline_order': 5}
# 72.25889098839531
# {'activation_scale': 2.771934801319548, 'grid_eps': 0.010058773650202775, 'grid_size': 4, 'lambda_l1': 3.444593186466389e-05, 'lambda_l2': 9.684215450045046e-07, 'learning_rate': 0.0017210701100112942, 'non': 10, 'scale_base': 0.3819493555513165, 'scale_noise': 0.000405934378983486, 'scale_spline': 0.007550999644736454, 'spline_order': 2}
# {'activation_scale': 6.50899025947982, 'grid_eps': 0.0002170112572975556, 'grid_size': 2, 'lambda_l1': 0.0006565279811804268, 'lambda_l2': 0.0020578006854685823, 'learning_rate': 0.00020264715475322353, 'non': 10, 'scale_base': 0.013214545776799997, 'scale_noise': 0.0020776703132813863, 'scale_spline': 2.563029764145881e-05, 'spline_order': 5}
# 7886.903860708478
# {'activation_scale': 1.1296169064281338, 'grid_eps': 0.010386271505330056, 'grid_size': 7, 'lambda_l1': 0.0017918380999654893, 'lambda_l2': 1.0275482388589507e-07, 'learning_rate': 3.6333336754509775e-05, 'non': 8, 'scale_base': 0.005757108130276948, 'scale_noise': 2.038266945453904e-05, 'scale_spline': 0.00011265384422762141, 'spline_order': 1}
# 86.78498264297842
# {'activation_scale': 4.166787862957477, 'grid_eps': 0.004376183549840101, 'grid_size': 13, 'lambda_l1': 2.7805255820189707e-06, 'lambda_l2': 0.0002382257264885369, 'learning_rate': 0.001469401858635837, 'non': 12, 'scale_base': 0.001354996473570535, 'scale_noise': 0.005849109607995701, 'scale_spline': 0.0008242917953663475, 'spline_order': 3}
# 7843.4822842320245
# {'activation_scale': 4.7990223072826, 'grid_eps': 0.0009536771692318641, 'grid_size': 9, 'lambda_l1': 6.046480208705674e-06, 'lambda_l2': 6.688339195471723e-06, 'learning_rate': 2.4248838595166326e-05, 'non': 10, 'scale_base': 0.07224286419918786, 'scale_noise': 7.800280732585565e-05, 'scale_spline': 0.06802441232920182, 'spline_order': 9}
# 7602.65984759498
# {'activation_scale': 3.026962009260208, 'grid_eps': 0.085927486915138, 'grid_size': 4, 'lambda_l1': 5.03656582491576e-07, 'lambda_l2': 0.0005107054288424268, 'learning_rate': 8.02630855797264e-05, 'non': 20, 'scale_base': 3.06764137534046e-05, 'scale_noise': 0.0010838606052387544, 'scale_spline': 4.0425462916856737e-05, 'spline_order': 3}
# 68.69898521667571
# {'activation_scale': 5.332591229831686, 'grid_eps': 0.0005127099881537235, 'grid_size': 11, 'lambda_l1': 8.74456153300426e-05, 'lambda_l2': 5.672999797704551e-07, 'learning_rate': 0.04045255485830913, 'non': 18, 'scale_base': 0.9312833480147542, 'scale_noise': 0.0004373248616399302, 'scale_spline': 0.01141639147722146, 'spline_order': 10}
# 100%|██████████| 50/50 [58:37<00:00, 70.35s/trial, best loss: 60.77273606646122]
# Best hyperparameters: {'activation_scale': 4.16625931823347, 'grid_eps': 0.001983253382880312, 'grid_size': 1.0, 'lambda_l1': 0.00016180393052642696, 'lambda_l2': 3.1562455922965976e-06, 'learning_rate': 0.017925854926990625, 'non': 8.0, 'scale_base': 0.02905294185869081, 'scale_noise': 0.0005395441762639075, 'scale_spline': 0.006856934976852015, 'spline_order': 4.0}

# %%
param_df.to_csv(f'param_df{current_target}.csv')

# %%
checkpoint = torch.load(f"{current_target}_bestest_model.pth")
params1 = checkpoint['params']
model = KAN(
    layers_hidden=[8, params1['non'], 1],
    grid_size=params1['grid_size'],
    spline_order=params1['spline_order'],
    scale_noise=params1['scale_noise'],
    scale_base=params1['scale_base'],
    scale_spline=params1['scale_spline'],
    base_activation=nn.SiLU,
    grid_eps=params1['grid_eps'],
    grid_range=[0, 1],
    activation_scale=params1['activation_scale']
)
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_5956\836558021.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(f"{current_target}_bestest_model.pth")
# <All keys matched successfully>

# %%
model.eval()
with torch.no_grad():
    test_predictions = model(dataset['test_input'])
mse(dataset['test_label'].numpy(), test_predictions.numpy())**0.5
# Out:
# 60.62995094906313

# %%
r2_score(dataset['test_label'].numpy(), test_predictions.numpy())
# Out:
# 0.8669485378820447

# %% [markdown]
# # 3rd Output

# %%
df=pd.read_csv('data.csv',header=1)
df=df.drop(columns=['power','thr'])
current_target='te'

# %%
df = df.sort_index()
x = df.drop(columns=current_target)
y = df[current_target]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=70) #59 power, 80 thr, 70 te
set_seed(42)

# %%
dataset = {}
train_input=x_train.to_numpy()
train_label=y_train.to_numpy()
test_input=x_test.to_numpy()
test_label=y_test.to_numpy()

# %%
scaler_input = MinMaxScaler()

train_input_scaled = scaler_input.fit_transform(train_input)
test_input_scaled = scaler_input.transform(test_input)

dataset['train_input'] = torch.from_numpy(train_input_scaled).type(dtype)
dataset['test_input'] = torch.from_numpy(test_input_scaled).type(dtype)
dataset['train_label'] = torch.from_numpy(train_label[:,None]).type(dtype)
dataset['test_label'] = torch.from_numpy(test_label[:,None]).type(dtype)

# %%
space = {
    'grid_size': hp.quniform('grid_size', 1, 15, 1),
    'spline_order': hp.quniform('spline_order', 1, 10, 1),
    'scale_noise': hp.loguniform('scale_noise', np.log(1e-5), np.log(1e-1)),
    'scale_base': hp.loguniform('scale_base', np.log(1e-5), np.log(1e1)),
    'scale_spline': hp.loguniform('scale_spline', np.log(1e-5), np.log(1e1)),
    'learning_rate': hp.loguniform('learning_rate', np.log(1e-5), np.log(1e-1)),
    'lambda_l1': hp.loguniform('lambda_l1', np.log(1e-7), np.log(1e-1)),
    'lambda_l2': hp.loguniform('lambda_l2', np.log(1e-7), np.log(1e-1)),
    'grid_eps': hp.loguniform('grid_eps', np.log(1e-7), np.log(1e-1)),
    'non': hp.quniform('non', 8, 20, 2),
    'activation_scale': hp.uniform('activation_scale', 0.1, 10.0)  # Uniform distribution for activation_scale
}

# %%
param_df = pd.DataFrame(columns=['params', 'loss_curve_train', 'loss_curve_test', 'best_score'])
bestest_score = float('inf')
trial_no=0
  # Initialize global variable
def objective(params):
    global trial_no, bestest_score  # Declare global variables
    trial_no += 1
    params['grid_size'] = int(params['grid_size'])
    params['spline_order'] = int(params['spline_order'])
    params['non'] = int(params['non'])
    model = KAN(
        layers_hidden=[8, params['non'], 1],
        grid_size=params['grid_size'],
        spline_order=params['spline_order'],
        scale_noise=params['scale_noise'],
        scale_base=params['scale_base'],
        scale_spline=params['scale_spline'],
        base_activation=nn.SiLU,
        grid_eps=params['grid_eps'],
        grid_range=[0, 1],
        activation_scale=params['activation_scale']
    )
    
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=params['learning_rate'], weight_decay=params['lambda_l2'])
    num_epochs = 5000
    patience = 200
    best_loss = float('inf')
    epochs_no_improve = 0
    param_df['params'].loc[trial_no] = params
    training_loss = []
    test_loss = []
    set_seed(42)
    for epoch in range(num_epochs):
        set_seed(42)
        model.train()
        optimizer.zero_grad()
        predictions = model(dataset['train_input'])
        main_loss = criterion(predictions, dataset['train_label'])
        l1_loss = sum(p.abs().sum() for p in model.parameters())
        loss = main_loss + (params['lambda_l1'] * l1_loss)
        loss.backward()
        optimizer.step()
        training_loss.append(loss.item())
        
        model.eval()
        with torch.no_grad():
            val_predictions = model(dataset['test_input'])
            temp_score = mse(dataset['test_label'].cpu().numpy(), val_predictions.cpu().numpy())**0.5  # Move tensors to CPU before numpy
        test_loss.append(temp_score)
        
        if temp_score < best_loss:
            best_loss = temp_score
            epochs_no_improve = 0
            best_model_state = model.state_dict()
        else:
            epochs_no_improve += 1
        
        if epochs_no_improve >= patience:
            model.load_state_dict(best_model_state)
            break
        
        # Update the bestest score
        if temp_score < bestest_score:
            bestest_score = temp_score
            torch.save({'model_state_dict': best_model_state, 'params': params}, f"{current_target}_bestest_model.pth")
    
    model.eval()
    with torch.no_grad():
        test_predictions = model(dataset['test_input'])
    score = mse(dataset['test_label'].numpy(), test_predictions.numpy())**0.5  # Move tensors to CPU before numpy
    param_df.loc[trial_no] = [params, training_loss, test_loss, score]
    print(score)
    print(params)
    return score

# %%
trials = Trials()
best_params = fmin(fn=objective,
                   space=space,
                   algo=tpe.suggest,
                   max_evals=50,
                   trials=trials)
print("Best hyperparameters:", best_params)
# Out:
# 0.37114092265219306
# {'activation_scale': 4.9802904674953385, 'grid_eps': 0.006278485530050673, 'grid_size': 4, 'lambda_l1': 0.017315182597917686, 'lambda_l2': 0.021991556165951692, 'learning_rate': 0.04186662588299815, 'non': 12, 'scale_base': 0.0001758488754534371, 'scale_noise': 0.07519093506472314, 'scale_spline': 0.13395807078456534, 'spline_order': 1}
# 0.35839177678843626
# {'activation_scale': 1.9440951806056217, 'grid_eps': 0.031769593624000225, 'grid_size': 8, 'lambda_l1': 2.497923238795171e-07, 'lambda_l2': 1.4607924310618444e-05, 'learning_rate': 0.0034237085383365677, 'non': 12, 'scale_base': 0.002493716794239757, 'scale_noise': 2.4415378336765304e-05, 'scale_spline': 0.04569818446921411, 'spline_order': 2}
# 0.5118039596783984
# {'activation_scale': 9.93103133082008, 'grid_eps': 0.06900119708431204, 'grid_size': 10, 'lambda_l1': 1.3438965433304055e-05, 'lambda_l2': 0.036571903928043666, 'learning_rate': 0.03423941568485846, 'non': 14, 'scale_base': 0.006609308653478905, 'scale_noise': 3.687695044617517e-05, 'scale_spline': 6.74655761152026e-05, 'spline_order': 4}
# 0.6983847849631086
# {'activation_scale': 5.098993340920446, 'grid_eps': 0.024406248298943407, 'grid_size': 14, 'lambda_l1': 3.393467801040455e-05, 'lambda_l2': 0.0034099275619914834, 'learning_rate': 9.041524184224874e-05, 'non': 18, 'scale_base': 0.18467665216420362, 'scale_noise': 2.430961640064097e-05, 'scale_spline': 0.015843110947962608, 'spline_order': 2}
# 0.3873902537075542
# {'activation_scale': 2.695557018155815, 'grid_eps': 4.838620760831119e-07, 'grid_size': 14, 'lambda_l1': 0.003199136551083042, 'lambda_l2': 5.719996156445267e-05, 'learning_rate': 0.012703731496128792, 'non': 12, 'scale_base': 4.994445765069383, 'scale_noise': 5.502319554141416e-05, 'scale_spline': 0.0017461138992736467, 'spline_order': 9}
# {'activation_scale': 1.2984671583331933, 'grid_eps': 8.478747076011174e-06, 'grid_size': 5, 'lambda_l1': 4.2968038896932915e-05, 'lambda_l2': 1.9292356356511162e-06, 'learning_rate': 0.0010992129057034224, 'non': 20, 'scale_base': 0.004360365136412984, 'scale_noise': 0.005399911980915076, 'scale_spline': 0.18649546295733285, 'spline_order': 9}
# 0.5192382337906802
# {'activation_scale': 1.0414956718389465, 'grid_eps': 0.00015931512735479255, 'grid_size': 1, 'lambda_l1': 0.03735100787225023, 'lambda_l2': 1.5198122393401394e-07, 'learning_rate': 0.002961392823044147, 'non': 12, 'scale_base': 0.000248444996464817, 'scale_noise': 0.0005346297757090189, 'scale_spline': 0.08276518845018233, 'spline_order': 6}
# 0.32039253211448493
# {'activation_scale': 3.2766638107272255, 'grid_eps': 0.0008280123011095639, 'grid_size': 5, 'lambda_l1': 0.003595804705923332, 'lambda_l2': 1.0399424951915855e-05, 'learning_rate': 0.008220078369004147, 'non': 18, 'scale_base': 4.077499185965501e-05, 'scale_noise': 0.0013977318398641604, 'scale_spline': 0.5467663654883329, 'spline_order': 8}
# 0.3332516479308417
# {'activation_scale': 1.686166155998966, 'grid_eps': 0.0008144287734711078, 'grid_size': 3, 'lambda_l1': 0.0002695349815884354, 'lambda_l2': 1.1865374007635593e-05, 'learning_rate': 0.051338744659440716, 'non': 18, 'scale_base': 3.218704630607095e-05, 'scale_noise': 0.0015665511726258548, 'scale_spline': 0.004686563754150596, 'spline_order': 9}
# 0.41820102545168725
# {'activation_scale': 3.1631508590905373, 'grid_eps': 0.08172754749034099, 'grid_size': 8, 'lambda_l1': 4.1696635100945056e-05, 'lambda_l2': 0.00018410643427106717, 'learning_rate': 0.026121800548394452, 'non': 18, 'scale_base': 6.062306277073718e-05, 'scale_noise': 0.08127767957545837, 'scale_spline': 0.0001474013103846352, 'spline_order': 5}
# 0.4259443691544006
# {'activation_scale': 0.5621538027657654, 'grid_eps': 0.014178445353494488, 'grid_size': 9, 'lambda_l1': 0.0018637851876157911, 'lambda_l2': 2.370512476108251e-05, 'learning_rate': 0.009448209450019892, 'non': 16, 'scale_base': 0.0004264616546496591, 'scale_noise': 0.00019072718035705548, 'scale_spline': 0.28968338309532865, 'spline_order': 10}
# 0.41098716427387766
# {'activation_scale': 1.8646893618435199, 'grid_eps': 0.000430716751264878, 'grid_size': 11, 'lambda_l1': 0.008977747951514608, 'lambda_l2': 4.9753165415557766e-05, 'learning_rate': 0.018241549671749478, 'non': 12, 'scale_base': 2.1798897293065733e-05, 'scale_noise': 0.0071599290906098284, 'scale_spline': 0.9715407673020614, 'spline_order': 4}
# 0.3944042899096683
# {'activation_scale': 4.082119414342308, 'grid_eps': 0.00425347044025851, 'grid_size': 2, 'lambda_l1': 1.1871116583188873e-06, 'lambda_l2': 0.07424220043163998, 'learning_rate': 0.006968598601757636, 'non': 18, 'scale_base': 0.09181470726552332, 'scale_noise': 0.016973495343669848, 'scale_spline': 0.03941333952530669, 'spline_order': 9}
# 0.3394096626221734
# {'activation_scale': 2.7553104679975244, 'grid_eps': 0.00037790636599911704, 'grid_size': 8, 'lambda_l1': 0.01870029490328951, 'lambda_l2': 1.6703155931771726e-05, 'learning_rate': 0.0008297635942373223, 'non': 16, 'scale_base': 0.003122313875894113, 'scale_noise': 0.0006844146604830169, 'scale_spline': 0.008072497373934711, 'spline_order': 4}
# 0.7028796130496343
# {'activation_scale': 1.7670265078229912, 'grid_eps': 0.0008175602437674842, 'grid_size': 10, 'lambda_l1': 0.004935234977190002, 'lambda_l2': 0.0015966292247541372, 'learning_rate': 0.00016490694419894682, 'non': 18, 'scale_base': 0.1341658034253635, 'scale_noise': 0.010127821967806497, 'scale_spline': 0.5964123570824486, 'spline_order': 3}
# 0.3755337862835224
# {'activation_scale': 5.787374443905781, 'grid_eps': 0.027232833336894875, 'grid_size': 9, 'lambda_l1': 0.00048055176117124226, 'lambda_l2': 9.261909171713625e-07, 'learning_rate': 0.002193054379906425, 'non': 10, 'scale_base': 0.000631276037810146, 'scale_noise': 0.00021880452562291869, 'scale_spline': 1.7506223207705425, 'spline_order': 7}
# 0.31688868312581225
# {'activation_scale': 4.8850051922015245, 'grid_eps': 0.006364941952844866, 'grid_size': 5, 'lambda_l1': 1.672392778942267e-07, 'lambda_l2': 0.0002825356534608033, 'learning_rate': 0.09593500157185111, 'non': 14, 'scale_base': 1.996931479420824, 'scale_noise': 0.0012426824365604282, 'scale_spline': 0.0005984384151777283, 'spline_order': 5}
# 0.37483131756094384
# {'activation_scale': 5.206079947906282, 'grid_eps': 3.1016499408847547e-06, 'grid_size': 3, 'lambda_l1': 4.639997729934993e-07, 'lambda_l2': 0.03354318178103058, 'learning_rate': 0.08302211324841405, 'non': 14, 'scale_base': 1.8274049291447487, 'scale_noise': 0.03200351708288156, 'scale_spline': 0.000297704250142232, 'spline_order': 5}
# 100%|██████████| 50/50 [59:10<00:00, 71.00s/trial, best loss: 0.31688868312581225]
# Best hyperparameters: {'activation_scale': 4.8850051922015245, 'grid_eps': 0.006364941952844866, 'grid_size': 5.0, 'lambda_l1': 1.672392778942267e-07, 'lambda_l2': 0.0002825356534608033, 'learning_rate': 0.09593500157185111, 'non': 14.0, 'scale_base': 1.996931479420824, 'scale_noise': 0.0012426824365604282, 'scale_spline': 0.0005984384151777283, 'spline_order': 5.0}

# %%
param_df.to_csv(f'param_df{current_target}.csv')

# %%
checkpoint = torch.load(f"{current_target}_bestest_model.pth")
params1 = checkpoint['params']
model = KAN(
    layers_hidden=[8, params1['non'], 1],
    grid_size=params1['grid_size'],
    spline_order=params1['spline_order'],
    scale_noise=params1['scale_noise'],
    scale_base=params1['scale_base'],
    scale_spline=params1['scale_spline'],
    base_activation=nn.SiLU,
    grid_eps=params1['grid_eps'],
    grid_range=[0, 1],
    activation_scale=params1['activation_scale']
)
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_5956\836558021.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(f"{current_target}_bestest_model.pth")
# <All keys matched successfully>

# %%
model.eval()
with torch.no_grad():
    test_predictions = model(dataset['test_input'])
mse(dataset['test_label'].numpy(), test_predictions.numpy())
# Out:
# 0.0973964089006034

# %%
r2_score(dataset['test_label'].numpy(), test_predictions.numpy())
# Out:
# 0.9115203555267788
